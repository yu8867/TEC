# %%
from module.run import Main
# Out:
# total base parameters 385030726
# total upsampler parameters 398361286

# %%
title = "押絵と旅する男"
num = 3
Main(title, num)
# Out:
# [3, 16, 17, 18, 19, 20, 21, 24, 35, 36, 37, 38, 39, 42, 43, 67, 68, 71, 72, 74, 76, 77, 78]
# Line drawing that The scenery in the dream, like in the film, is completely colourless, but the scenery in the train on that occasion, centred on that poisonous oshie screen, is vividly etched in my memory, like the pupil of a snake's eye, in the colours of purple and dark red.
# image
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F6B10E6ED60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F6B10E6E910>
# Line drawing that The scenery in the dream, like in the film, is completely colourless, but the scenery in the train on that occasion, centred on that poisonous oshie screen, is vividly etched in my memory, like the pupil of a snake's eye, in the colours of purple and dark red.
# image
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F6B10E6ED60>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F6B10E6E7F0>
# ...
